# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/home/ilya/Documents/stress-level-by-PPG/working with WESAD/ppg_feature.csv")
data.head()
# Out:
#    HRV_MeanNN    HRV_SDNN   HRV_RMSSD    HRV_SDSD  HRV_CVNN  HRV_CVSD  \
# 0  706.881010   91.746035  135.595835  138.391552  0.129790  0.191823
# 1  718.750000  110.568268  180.219999  183.836414  0.153834  0.250741
# 2  734.074519  152.637630  268.813583  274.350040  0.207932  0.366194
# 3  715.895433  137.994307  238.598662  243.006428  0.192758  0.333287
# 4  706.881010   91.746035  135.595835  138.391552  0.129790  0.191823
#
#    HRV_MedianNN   HRV_MadNN  HRV_pNN50  HRV_pNN20  HRV_MinNN   HRV_MaxNN  \
# 0    699.218750   37.644141  50.000000  73.076923  472.65625   945.31250
# 1    699.218750   57.914062  61.538462  76.923077  531.25000  1003.90625
# 2    736.328125  194.012109  84.615385  96.153846  433.59375  1003.90625
# 3    699.218750  133.202344  80.769231  84.615385  433.59375   980.46875
# 4    699.218750   37.644141  50.000000  73.076923  472.65625   945.31250
#
#     HRV_HTI  HRV_TINN    HRV_HF  stress_index
# 0  8.666667  234.3750  0.076577           0.0
# 1  8.666667  164.0625  0.112954           0.0
# 2  8.666667  304.6875  0.064073           0.0
# 3  8.666667  179.6875  0.050485           0.0
# 4  8.666667  234.3750  0.076577           0.0

# %%
rows_to_delete = data[data.isna().any(axis=1)]
data = data.dropna()
data.to_csv('./ppg_feature.csv', index=False)
rows_to_delete
# Out:
# Empty DataFrame
# Columns: [HRV_MeanNN, HRV_SDNN, HRV_RMSSD, HRV_SDSD, HRV_CVNN, HRV_CVSD, HRV_MedianNN, HRV_MadNN, HRV_pNN50, HRV_pNN20, HRV_MinNN, HRV_MaxNN, HRV_HTI, HRV_TINN, HRV_HF, stress_index]
# Index: []

# %%
correlation_matrix = data.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, cmap='coolwarm')
plt.title('Матрица корреляции')
plt.show()

# %%
mini_data = data[['HRV_SDNN', 'HRV_MeanNN', 'stress_index']]

plt.figure(figsize=(10, 6))
sns.scatterplot(data=mini_data, x='HRV_SDNN', y='HRV_MeanNN', hue='stress_index', palette='viridis', s=100)
plt.title('')
plt.xlabel('HRV_SDNN')
plt.ylabel('HRV_MeanNN')
plt.legend(title='intensity')
# plt.savefig(f'/home/ilya/Documents/stress-level-by-PPG/corr2_HRV_MeanNN_HRV_SDNN.png', dpi=300, bbox_inches='tight')
plt.show()
