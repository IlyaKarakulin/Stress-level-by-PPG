# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_pickle(f'/home/ilya/Documents/stress-level-by-PPG/data.pkl')

# %%
reference_wave = np.squeeze(data["S2"]["PPG_medit"][1413:1470])

plt.figure(figsize=(2, 4))
plt.plot(reference_wave)
plt.title("Чистый сигнал")
plt.ylim(-40, 40)
plt.grid(True)

# %%
np.save('./reference_wave.npy', reference_wave)
